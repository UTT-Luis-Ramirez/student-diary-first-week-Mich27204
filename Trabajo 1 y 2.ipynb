# %% [markdown]
# TRABAJO 1
# Termino
# Estadisticas: ¿Que se? la estadistica es una rama de las matematicas que se enfoca en realizar analisis y presentacion de datos y nos ayudan a entender patrones.                                                                        ¿Que deseo saber? quiero saber la forma mas facil de aplicar la estadistica
#
# Dato: ¿Que se? los datos son informacion que se nos informa mediante noticias o eventos que hayan sucedidos
# ¿Que deseo saber?cual es la mejor forma de proporcionar datos y mas eficiente.
#
# Teoria de conjuntos
# ¿Que se?es una rama de las matematicas que estudia las colecciones de objetos.
# ¿Que deseo saber? cual seria la froma mas facil o mas comprensiva de entender esta teoria de conjuntos.
#
# Axiomas:¿Que se?son proposiciones o enunciados básicos que se aceptan como verdaderos sin necesidad de demostración dentro de un sistema lógico o matemático.¿Que deseo saber?quiero saber una forma de aplicar esto y entenderlo mas a fondo.
#
# Eventos:¿Que se?son sucesos pasados o que van a ocurrir en un lapso de tiempo.
# ¿Que deseo saber?deseo conocerla mas afondo.
#
# Probabilidad:¿Que se?la probabilidad es un suceso de suerte que decide si sucedera o no puede ser una suerte del 1 al 10.
# ¿Que deso saber?conocer mas a fondo la probabilidad para saber aplicarla mejor.

# %% [markdown]
# TRABAJO 2 control de calidad de software. resumir los datos, areas poblematicas y mejorar estas areas
#
# La calidad de velocidad de la aplicacion, el espacio que abarca en el dispositivo que se este utilizando, la calidad de imagen en este, la duracion permitida por video, la proteccion de informacion,tambien nos centramos en las actualizaciones para llevar una control mejor del software de la plataforma.
#
# Problematica seguridad de ususario, iniciacion lentas.
#
# para mejorar en las areas poblematicas y en todo el software estaremos metiendo actualizaciones cada mas y parches para arreglar los problemas que hayan surgido
